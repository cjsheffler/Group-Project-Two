# %%
# import data from the csv
import pandas as pd
import numpy as py
import requests
import json

csv_file = "netflix_data_clean.csv"
netflix_file_clean_df = pd.read_csv(csv_file)
netflix_file_clean_df.head()
# Out:
#    Unnamed: 0   show_id   type               title          director  \
# 0           4  80125979  Movie        #realityhigh  Fernando Lebrija
# 1          20  80060297  Movie   Manhattan Romance       Tom O'Brien
# 2          23  70304988  Movie  Stonehearst Asylum     Brad Anderson
# 3          24  80057700  Movie          The Runner      Austin Stark
# 4          25  80045922  Movie             6 Years     Hannah Fidell
#
#                                                 cast        country  \
# 0  Nesta Cooper, Kate Walsh, John Michael Higgins...  United States
# 1  Tom O'Brien, Katherine Waterston, Caitlin Fitz...  United States
# 2  Kate Beckinsale, Jim Sturgess, David Thewlis, ...  United States
# 3  Nicolas Cage, Sarah Paulson, Connie Nielsen, W...  United States
# 4  Taissa Farmiga, Ben Rosenfield, Lindsay Burdge...  United States
#
#           date_added  release_year rating duration  \
# 0  September 8, 2017          2017  TV-14   99 min
# ...

# %%
# Grab a small subset of data for testing
test_data = netflix_file_clean_df.loc[netflix_file_clean_df["director"] == "Troy Miller"]
test_data.head()
# Out:
#      Unnamed: 0   show_id   type                                        title  \
# 22          126  81074113  Movie                  Jeff Dunham: Beside Himself
# 43          210  80108371  Movie  Cedric the Entertainer: Live from the Ville
# 197        1158  80134827  Movie     Brian Regan: Nunchucks and Flamethrowers
#
#         director                    cast        country          date_added  \
# 22   Troy Miller             Jeff Dunham  United States  September 24, 2019
# 43   Troy Miller  Cedric the Entertainer  United States  September 16, 2016
# 197  Troy Miller             Brian Regan  United States   November 21, 2017
#
#      release_year rating duration        listed_in  \
# 22           2019  TV-MA   58 min  Stand-Up Comedy
# 43           2016  TV-MA   60 min  Stand-Up Comedy
# 197          2017  TV-PG   61 min  Stand-Up Comedy
#
#                                            description
# 22   Jeff Dunham takes the stage in Dallas with his...
# ...

# %%
#iterate through the titles and add information into list or dictionary
url = "http://www.omdbapi.com/?apikey=trilogy&t="
titles = netflix_file_clean_df["title"]
movie_name = []
genre = []
language = []
awards = []
metascore = []
boxoffice = []
production = []
imdbrating = []
imdbvotes = []
imdbid = []

for title in titles:
    response = requests.get(url + title)
    response_json = response.json()
    
    try:
        movie_name.append(response_json['Title'])
    except:
        movie_name.append('na')
        
    try:
        genre.append(response_json['Genre'])
    except:
        genre.append('na')
        
    try:
        language.append(response_json['Language'])
    except:
        language.append('na')
        
    try:
        awards.append(response_json['Awards'])
    except:
        awards.append('na')
        
    try:
        metascore.append(response_json['Metascore'])
    except:
        metascore.append('na')
        
    try:
        boxoffice.append(response_json['BoxOffice'])
    except:
        boxoffice.append('na')
        
    try:
        production.append(response_json['Production'])
    except:
        production.append('na')
        
    try:
        imdbrating.append(response_json['imdbRating'])
    except:
        imdbrating.append('na')
        
    try:
        imdbvotes.append(response_json['imdbVotes'])
    except:
        imdbvotes.append('na')
        
    try:
        imdbid.append(response_json['imdbID'])
    except:
        imdbid.append('na')

# %%
# add the information into a single dataframe
omdb_data = pd.DataFrame({
    'title':movie_name,
    'genre':genre,
    'language':language,
    'awards':awards,
    'metascore':metascore,
    'boxoffice':boxoffice,
    'production':production,
    'imdbrating':imdbrating,
    'imdbvotes':imdbvotes,
    'imdbid':imdbid
})

# %%
#print(movie_name)

# %%
# double check data
omdb_data.head()
# Out:
#                 title                    genre language  \
# 0                  na                       na       na
# 1   Manhattan Romance   Comedy, Drama, Romance  English
# 2  Stonehearst Asylum  Drama, Horror, Thriller  English
# 3          The Runner                    Drama  English
# 4             6 Years           Drama, Romance  English
#
#                   awards metascore boxoffice               production  \
# 0                     na        na        na                       na
# 1                3 wins.       N/A       N/A        Beacon Films Inc.
# 2  1 win & 1 nomination.        52       N/A  Millenium Entertainment
# 3                    N/A        39       N/A                  Alchemy
# 4         4 nominations.        53       N/A                      N/A
#
#   imdbrating imdbvotes     imdbid
# 0         na        na         na
# 1        5.5     1,122  tt2608324
# 2        6.8    48,493  tt1772264
# 3        4.7     4,768  tt3687398
# ...

# %%
# remove any results where the title was na
omdb_data_clean = omdb_data
omdb_data_clean = omdb_data_clean.loc[omdb_data_clean["title"]!= 'na']
omdb_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 901 entries, 1 to 966
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       901 non-null    object
#  1   genre       901 non-null    object
#  2   language    901 non-null    object
#  3   awards      901 non-null    object
#  4   metascore   901 non-null    object
#  5   boxoffice   901 non-null    object
#  6   production  901 non-null    object
#  7   imdbrating  901 non-null    object
#  8   imdbvotes   901 non-null    object
#  9   imdbid      901 non-null    object
# dtypes: object(10)
# memory usage: 77.4+ KB

# %%
# save to csv
omdb_data_clean.to_csv("omdb_data_clean.csv", index=True)
