# %%
import pandas as pd
from sqlalchemy import create_engine

import psycopg2
import matplotlib.pyplot as plt
from configparser import ConfigParser

# %% [markdown]
# Extract CSV files into DataFrames

# %%
netflix_file = "netflix_data_clean.csv"
netflix_df = pd.read_csv(netflix_file)
netflix_df.head()
# Out:
#    Unnamed: 0   show_id   type               title          director  \
# 0           4  80125979  Movie        #realityhigh  Fernando Lebrija
# 1          20  80060297  Movie   Manhattan Romance       Tom O'Brien
# 2          23  70304988  Movie  Stonehearst Asylum     Brad Anderson
# 3          24  80057700  Movie          The Runner      Austin Stark
# 4          25  80045922  Movie             6 Years     Hannah Fidell
#
#                                                 cast        country  \
# 0  Nesta Cooper, Kate Walsh, John Michael Higgins...  United States
# 1  Tom O'Brien, Katherine Waterston, Caitlin Fitz...  United States
# 2  Kate Beckinsale, Jim Sturgess, David Thewlis, ...  United States
# 3  Nicolas Cage, Sarah Paulson, Connie Nielsen, W...  United States
# 4  Taissa Farmiga, Ben Rosenfield, Lindsay Burdge...  United States
#
#           date_added  release_year rating duration  \
# 0  September 8, 2017          2017  TV-14   99 min
# 1  September 8, 2017          2014  TV-14   98 min
# 2  September 8, 2017          2014  PG-13  113 min
# 3  September 8, 2017          2015      R   90 min
# 4  September 8, 2015          2015     NR   80 min
#
#                                        listed_in  \
# 0                                       Comedies
# 1  Comedies, Independent Movies, Romantic Movies
# 2                       Horror Movies, Thrillers
# 3                     Dramas, Independent Movies
# 4    Dramas, Independent Movies, Romantic Movies
#
#                                          description
# 0  When nerdy high schooler Dani finally attracts...
# 1  A filmmaker working on a documentary about lov...
# 2  In 1899, a young doctor arrives at an asylum f...
# 3  A New Orleans politician finds his idealistic ...
# 4  As a volatile young couple who have been toget...

# %%
omdb_file = "omdb_data_clean.csv"
omdb_df = pd.read_csv(omdb_file)
omdb_df.head()
# Out:
#    Unnamed: 0                      title                    genre language  \
# 0           1          Manhattan Romance   Comedy, Drama, Romance  English
# 1           2         Stonehearst Asylum  Drama, Horror, Thriller  English
# 2           3                 The Runner                    Drama  English
# 3           4                    6 Years           Drama, Romance  English
# 4           5  Sierra Burgess Is a Loser   Comedy, Drama, Romance  English
#
#                   awards  metascore boxoffice               production  \
# 0                3 wins.        NaN       NaN        Beacon Films Inc.
# 1  1 win & 1 nomination.       52.0       NaN  Millenium Entertainment
# 2                    NaN       39.0       NaN                  Alchemy
# 3         4 nominations.       53.0       NaN                      NaN
# 4         2 nominations.       60.0       NaN                  Netflix
#
#    imdbrating imdbvotes     imdbid
# 0         5.5     1,122  tt2608324
# 1         6.8    48,493  tt1772264
# 2         4.7     4,768  tt3687398
# 3         5.6    10,784  tt3799372
# 4         5.9    31,443  tt3120280

# %%
tmdb_file = "tmdb_data_clean.csv"
tmdb_df = pd.read_csv(tmdb_file)
tmdb_df.head()
# Out:
#    Unnamed: 0                      title             original_title  \
# 0           1          Manhattan Romance          Manhattan Romance
# 1           2         Stonehearst Asylum         Stonehearst Asylum
# 2           3                 The Runner                 The Runner
# 3           4                    6 Years                    6 Years
# 4           5  Sierra Burgess Is a Loser  Sierra Burgess Is a Loser
#
#    popularity  vote_count  vote_average  \
# 0       3.919          24           4.8
# 1      20.826         817           6.7
# 2       9.011         104           4.8
# 3       6.515         594           5.5
# 4      19.091        2689           6.4
#
#                                          poster_path
# 0                                                 na
# 1  https://image.tmdb.org/t/p/w500/fZxGCCQ0NAtrae...
# 2  https://image.tmdb.org/t/p/w500/uIxFfrGlKEHJgk...
# 3                                                 na
# 4  https://image.tmdb.org/t/p/w500/vjnHRySiVM4YcB...

# %% [markdown]
# Transform Netflix and the Open Movie DB DataFrames

# %%
# Create a filtered on the Netflix dataframe from specific columns
netflix_columns = ["show_id", "title", "director", "cast", "release_year", "listed_in", "rating", "duration", "description"]
netflix_transformed= netflix_df[netflix_columns].copy()

# Rename the column headers
netflix_transformed = netflix_transformed.rename(columns={"show_id": "id",
                                                          "listed_in": "netflix_genre", 
                                                          "release_year": "year_released", 
                                                          "cast":"cast_members"})

# Clean the data by dropping duplicates and setting the index
netflix_transformed.drop_duplicates("id", inplace=True)
netflix_transformed.set_index("id", inplace=True)

netflix_transformed.head()
# Out:
#                        title          director  \
# id
# 80125979        #realityhigh  Fernando Lebrija
# 80060297   Manhattan Romance       Tom O'Brien
# 70304988  Stonehearst Asylum     Brad Anderson
# 80057700          The Runner      Austin Stark
# 80045922             6 Years     Hannah Fidell
#
#                                                cast_members  year_released  \
# id
# 80125979  Nesta Cooper, Kate Walsh, John Michael Higgins...           2017
# 80060297  Tom O'Brien, Katherine Waterston, Caitlin Fitz...           2014
# 70304988  Kate Beckinsale, Jim Sturgess, David Thewlis, ...           2014
# 80057700  Nicolas Cage, Sarah Paulson, Connie Nielsen, W...           2015
# 80045922  Taissa Farmiga, Ben Rosenfield, Lindsay Burdge...           2015
#
#                                           netflix_genre rating duration  \
# id
# 80125979                                       Comedies  TV-14   99 min
# 80060297  Comedies, Independent Movies, Romantic Movies  TV-14   98 min
# 70304988                       Horror Movies, Thrillers  PG-13  113 min
# 80057700                     Dramas, Independent Movies      R   90 min
# 80045922    Dramas, Independent Movies, Romantic Movies     NR   80 min
#
#                                                 description
# id
# 80125979  When nerdy high schooler Dani finally attracts...
# 80060297  A filmmaker working on a documentary about lov...
# 70304988  In 1899, a young doctor arrives at an asylum f...
# 80057700  A New Orleans politician finds his idealistic ...
# 80045922  As a volatile young couple who have been toget...

# %%
 # Create a filtered on the Open Move DB dataframe from specific columns
omdb_columns = ["title", "genre", "language", "awards", "production", "imdbid", "imdbrating", "metascore", "boxoffice"]
omdb_transformed= omdb_df[omdb_columns].copy()

omdb_transformed = omdb_transformed.rename(columns={"genre": "omdb_genre"})

omdb_transformed["boxoffice"]=omdb_transformed["boxoffice"].str.replace('$', '')
omdb_transformed["boxoffice"]=omdb_transformed["boxoffice"].str.replace(',', '')
#omdb_transformed["boxoffice"]=omdb_transformed["boxoffice"].astype(float)

# Clean the data by dropping duplicates and setting the index
omdb_transformed.drop_duplicates("imdbid", inplace=True)
omdb_transformed.set_index("imdbid", inplace=True)

omdb_transformed
# Out:
#                                       title  \
# imdbid
# tt2608324                 Manhattan Romance
# tt1772264                Stonehearst Asylum
# tt3687398                        The Runner
# tt3799372                           6 Years
# tt3120280         Sierra Burgess Is a Loser
# ...                                     ...
# tt5420376                         Riverdale
# tt3107288                         The Flash
# tt2193021                             Arrow
# tt1319735                       Royal Pains
# tt2314952  Comedians in Cars Getting Coffee
#
#                                                  omdb_genre  \
# imdbid
# tt2608324                            Comedy, Drama, Romance
# tt1772264                           Drama, Horror, Thriller
# tt3687398                                             Drama
# tt3799372                                    Drama, Romance
# tt3120280                            Comedy, Drama, Romance
# ...                                                     ...
# tt5420376                    Crime, Drama, Mystery, Romance
# tt3107288                  Action, Adventure, Drama, Sci-Fi
# tt2193021  Action, Adventure, Crime, Drama, Mystery, Sci-Fi
# tt1319735                                     Comedy, Drama
# tt2314952                                 Comedy, Talk-Show
#
#                                    language  \
# imdbid
# tt2608324                           English
# tt1772264                           English
# tt3687398                           English
# tt3799372                           English
# tt3120280                           English
# ...                                     ...
# tt5420376                           English
# tt3107288                           English
# tt2193021                           English
# tt1319735  English, Spanish, French, German
# tt2314952                           English
#
#                                                       awards  \
# imdbid
# tt2608324                                            3 wins.
# tt1772264                              1 win & 1 nomination.
# tt3687398                                                NaN
# tt3799372                                     4 nominations.
# tt3120280                                     2 nominations.
# ...                                                      ...
# tt5420376                          30 wins & 39 nominations.
# tt3107288  Nominated for 1 Primetime Emmy. Another 26 win...
# tt2193021                          21 wins & 82 nominations.
# tt1319735                            2 wins & 2 nominations.
# tt2314952  Nominated for 4 Primetime Emmys. Another 11 wi...
#
#                         production  imdbrating  metascore boxoffice
# imdbid
# tt2608324        Beacon Films Inc.         5.5        NaN       NaN
# tt1772264  Millenium Entertainment         6.8       52.0       NaN
# tt3687398                  Alchemy         4.7       39.0       NaN
# tt3799372                      NaN         5.6       53.0       NaN
# tt3120280                  Netflix         5.9       60.0       NaN
# ...                            ...         ...        ...       ...
# tt5420376                       na         7.1        NaN        na
# tt3107288                       na         7.8        NaN        na
# tt2193021                       na         7.6        NaN        na
# tt1319735                       na         7.0        NaN        na
# tt2314952                       na         8.1        NaN        na
#
# [1239 rows x 8 columns]

# %%
 # Create a filtered on the Open Move DB dataframe from specific columns
tmdb_columns = ["title", "original_title", "popularity", "vote_count", "vote_average", "poster_path"]
tmdb_transformed= tmdb_df[tmdb_columns].copy()

tmdb_transformed.head()
# Out:
#                        title             original_title  popularity  \
# 0          Manhattan Romance          Manhattan Romance       3.919
# 1         Stonehearst Asylum         Stonehearst Asylum      20.826
# 2                 The Runner                 The Runner       9.011
# 3                    6 Years                    6 Years       6.515
# 4  Sierra Burgess Is a Loser  Sierra Burgess Is a Loser      19.091
#
#    vote_count  vote_average                                        poster_path
# 0          24           4.8                                                 na
# 1         817           6.7  https://image.tmdb.org/t/p/w500/fZxGCCQ0NAtrae...
# 2         104           4.8  https://image.tmdb.org/t/p/w500/uIxFfrGlKEHJgk...
# 3         594           5.5                                                 na
# 4        2689           6.4  https://image.tmdb.org/t/p/w500/vjnHRySiVM4YcB...

# %% [markdown]
# Create a DB connection

# %%
connection_string = "postgres:postgres@localhost:5432/movies_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables were created
engine.table_names()
# Out:
# ['omdb', 'netflix', 'tmdb']

# %% [markdown]
# Load Transformed DF data into the DB

# %%
netflix_transformed.to_sql(name='netflix', con=engine, if_exists='append', index=True)

# %%
omdb_transformed.to_sql(name='omdb', con=engine, if_exists='append', index=True)

# %%
tmdb_transformed.to_sql(name='tmdb', con=engine, if_exists='append', index=False)

# %%
merge_table1 = pd.merge(netflix_transformed, omdb_transformed, on="title", how="outer")
merge_table1.head()
# Out:
#                 title          director  \
# 0        #realityhigh  Fernando Lebrija
# 1   Manhattan Romance       Tom O'Brien
# 2  Stonehearst Asylum     Brad Anderson
# 3          The Runner      Austin Stark
# 4             6 Years     Hannah Fidell
#
#                                         cast_members  year_released  \
# 0  Nesta Cooper, Kate Walsh, John Michael Higgins...         2017.0
# 1  Tom O'Brien, Katherine Waterston, Caitlin Fitz...         2014.0
# 2  Kate Beckinsale, Jim Sturgess, David Thewlis, ...         2014.0
# 3  Nicolas Cage, Sarah Paulson, Connie Nielsen, W...         2015.0
# 4  Taissa Farmiga, Ben Rosenfield, Lindsay Burdge...         2015.0
#
#                                    netflix_genre rating duration  \
# 0                                       Comedies  TV-14   99 min
# 1  Comedies, Independent Movies, Romantic Movies  TV-14   98 min
# 2                       Horror Movies, Thrillers  PG-13  113 min
# 3                     Dramas, Independent Movies      R   90 min
# 4    Dramas, Independent Movies, Romantic Movies     NR   80 min
#
#                                          description               omdb_genre  \
# 0  When nerdy high schooler Dani finally attracts...                      NaN
# 1  A filmmaker working on a documentary about lov...   Comedy, Drama, Romance
# 2  In 1899, a young doctor arrives at an asylum f...  Drama, Horror, Thriller
# 3  A New Orleans politician finds his idealistic ...                    Drama
# 4  As a volatile young couple who have been toget...           Drama, Romance
#
#   language                 awards               production  imdbrating  \
# 0      NaN                    NaN                      NaN         NaN
# 1  English                3 wins.        Beacon Films Inc.         5.5
# 2  English  1 win & 1 nomination.  Millenium Entertainment         6.8
# 3  English                    NaN                  Alchemy         4.7
# 4  English         4 nominations.                      NaN         5.6
#
#    metascore boxoffice
# 0        NaN       NaN
# 1        NaN       NaN
# 2       52.0       NaN
# 3       39.0       NaN
# 4       53.0       NaN

# %%
final_table = pd.merge(merge_table1, tmdb_transformed, on="title", how="outer")
final_table_clean = final_table.drop_duplicates("title")
final_table_clean
# Out:
#                                                   title          director  \
# 0                                          #realityhigh  Fernando Lebrija
# 1                                     Manhattan Romance       Tom O'Brien
# 2                                    Stonehearst Asylum     Brad Anderson
# 3                                            The Runner      Austin Stark
# 4                                               6 Years     Hannah Fidell
# ...                                                 ...               ...
# 1567  Emmanuelle Through Time: Emmanuelle's Supernat...               NaN
# 1568        DC's Legends of Tomorrow: Their Time Is Now               NaN
# 1569                Archie: To Riverdale and Back Again               NaN
# 1570                                Ricki and the Flash               NaN
# 1571                                       Broken Arrow               NaN
#
#                                            cast_members  year_released  \
# 0     Nesta Cooper, Kate Walsh, John Michael Higgins...         2017.0
# 1     Tom O'Brien, Katherine Waterston, Caitlin Fitz...         2014.0
# 2     Kate Beckinsale, Jim Sturgess, David Thewlis, ...         2014.0
# 3     Nicolas Cage, Sarah Paulson, Connie Nielsen, W...         2015.0
# 4     Taissa Farmiga, Ben Rosenfield, Lindsay Burdge...         2015.0
# ...                                                 ...            ...
# 1567                                                NaN            NaN
# 1568                                                NaN            NaN
# 1569                                                NaN            NaN
# 1570                                                NaN            NaN
# 1571                                                NaN            NaN
#
#                                       netflix_genre rating duration  \
# 0                                          Comedies  TV-14   99 min
# 1     Comedies, Independent Movies, Romantic Movies  TV-14   98 min
# 2                          Horror Movies, Thrillers  PG-13  113 min
# 3                        Dramas, Independent Movies      R   90 min
# 4       Dramas, Independent Movies, Romantic Movies     NR   80 min
# ...                                             ...    ...      ...
# 1567                                            NaN    NaN      NaN
# 1568                                            NaN    NaN      NaN
# 1569                                            NaN    NaN      NaN
# 1570                                            NaN    NaN      NaN
# 1571                                            NaN    NaN      NaN
#
#                                             description  \
# 0     When nerdy high schooler Dani finally attracts...
# 1     A filmmaker working on a documentary about lov...
# 2     In 1899, a young doctor arrives at an asylum f...
# 3     A New Orleans politician finds his idealistic ...
# 4     As a volatile young couple who have been toget...
# ...                                                 ...
# 1567                                                NaN
# 1568                                                NaN
# 1569                                                NaN
# 1570                                                NaN
# 1571                                                NaN
#
#                    omdb_genre language                 awards  \
# 0                         NaN      NaN                    NaN
# 1      Comedy, Drama, Romance  English                3 wins.
# 2     Drama, Horror, Thriller  English  1 win & 1 nomination.
# 3                       Drama  English                    NaN
# 4              Drama, Romance  English         4 nominations.
# ...                       ...      ...                    ...
# 1567                      NaN      NaN                    NaN
# 1568                      NaN      NaN                    NaN
# 1569                      NaN      NaN                    NaN
# 1570                      NaN      NaN                    NaN
# 1571                      NaN      NaN                    NaN
#
#                    production  imdbrating  metascore boxoffice  \
# 0                         NaN         NaN        NaN       NaN
# 1           Beacon Films Inc.         5.5        NaN       NaN
# 2     Millenium Entertainment         6.8       52.0       NaN
# 3                     Alchemy         4.7       39.0       NaN
# 4                         NaN         5.6       53.0       NaN
# ...                       ...         ...        ...       ...
# 1567                      NaN         NaN        NaN       NaN
# 1568                      NaN         NaN        NaN       NaN
# 1569                      NaN         NaN        NaN       NaN
# 1570                      NaN         NaN        NaN       NaN
# 1571                      NaN         NaN        NaN       NaN
#
#                                          original_title  popularity  \
# 0                                                   NaN         NaN
# 1                                     Manhattan Romance       3.919
# 2                                    Stonehearst Asylum      20.826
# 3                                            The Runner       9.011
# 4                                               6 Years       6.515
# ...                                                 ...         ...
# 1567  Emmanuelle Through Time: Emmanuelle's Supernat...       9.649
# 1568        DC's Legends of Tomorrow: Their Time Is Now       2.540
# 1569                Archie: To Riverdale and Back Again       2.478
# 1570                                Ricki and the Flash      11.206
# 1571                                       Broken Arrow      13.367
#
#       vote_count  vote_average  \
# 0            NaN           NaN
# 1           24.0           4.8
# 2          817.0           6.7
# 3          104.0           4.8
# 4          594.0           5.5
# ...          ...           ...
# 1567         2.0           8.3
# 1568        24.0           6.7
# 1569         9.0           6.1
# 1570       521.0           5.8
# 1571       823.0           5.9
#
#                                             poster_path
# 0                                                   NaN
# 1                                                    na
# 2     https://image.tmdb.org/t/p/w500/fZxGCCQ0NAtrae...
# 3     https://image.tmdb.org/t/p/w500/uIxFfrGlKEHJgk...
# 4                                                    na
# ...                                                 ...
# 1567                                                 na
# 1568                                                 na
# 1569  https://image.tmdb.org/t/p/w500/5VeJ2FNAg2SGam...
# 1570  https://image.tmdb.org/t/p/w500/l7Mx2KUT6BlD5v...
# 1571  https://image.tmdb.org/t/p/w500/2AlvHCeaZtFeR2...
#
# [1559 rows x 20 columns]

# %%
box_office_movies = final_table_clean.dropna(subset=["boxoffice"])
box_office_movies = box_office_movies.loc[box_office_movies["boxoffice"]!='na']
box_office_movies["boxoffice"] = box_office_movies["boxoffice"].astype(float)

# %%
box_office_movies.plot(kind='scatter', x='imdbrating', y='boxoffice')
plt.show()

# %%
final_table_clean.plot(kind='scatter', x='imdbrating', y='vote_count')
plt.show()

# %%
box_office_movies.plot(kind='scatter', x='boxoffice', y='vote_count')
plt.show()
